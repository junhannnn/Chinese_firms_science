# %%
import pandas as pd
import yaml
from pathlib import Path

from pandarallel import pandarallel
pandarallel.initialize(progress_bar=True, nb_workers=16)

# %%
import os
os.chdir('../../')

# %%
# Load configuration settings from a YAML file.
# The configuration file typically contains file paths and other parameters.
dataset_config = yaml.safe_load(open("config/dataset.yml"))
dataset_config

# %%
df_wos = pd.read_csv(dataset_config['path_processed'] + 'WOS/WOS_2010_2023.csv')
df_wos

# %%
unique_orgs = df_wos["organizations"].dropna().unique()

# %%
df_unique_orgs = pd.DataFrame(unique_orgs, columns=["organization"])
df_unique_orgs

# %%
df_unique_orgs[df_unique_orgs.organization.apply(lambda x: isinstance(x, str))].to_parquet(dataset_config['path_processed'] + 'WOS/WOS_unique_orgs.parquet')
