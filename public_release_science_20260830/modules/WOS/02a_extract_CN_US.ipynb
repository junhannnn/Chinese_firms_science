# %%
import pandas as pd

# Load the CSV
df = pd.read_csv("WOS_unique_orgs_with_country.csv")
df

# %%
# Filter for US and CN
filtered = df[df["country"].isin(["US", "CN"])]
filtered

# %%
filtered.to_parquet('02_WOS_unique_orgs_CN_US.parquet')
